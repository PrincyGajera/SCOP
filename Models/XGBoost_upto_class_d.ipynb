# %%
import pandas as pd
import seaborn as sb
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, recall_score, f1_score, classification_report

# %%
# !pip install -U xgboost
# Out:
# ...
#      |████████████████████████████████| 173.6 MB 6.7 kB/s
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# ...

# %%
from xgboost import XGBClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
accuracy_scores=[]

# %%
def classModel(data):
  X= data.iloc[:,:-1].values
  y= data.iloc[:,-1].values
  
  le = LabelEncoder()
  y= le.fit_transform(y) 

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 5)

  model = XGBClassifier()
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  print('Confusion matrix: \n', confusion_matrix(y_test,y_pred))

  accuracy = accuracy_score(y_test,y_pred)
  # accuracy_scores.append(accuracy)
  print("\n\nAccuracy:",accuracy_score(y_test, y_pred))

  print("\n\nPrecision:",precision_score(y_test, y_pred, average=None))
  print("\nRecall:",recall_score(y_test, y_pred, average=None))
  print("\nF1 score:",f1_score(y_test, y_pred, average=None))

# %% [markdown]
# #CTDC

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/output_csv_iFeature/CTDC_d.csv')
data.tail()
# Out:
#        hydrophobicity_PRAM900101.G1  ...  class
# 13052                      0.358140  ...      d
# 13053                      0.444730  ...      d
# 13054                      0.409160  ...      d
# 13055                      0.351767  ...      d
# 13056                      0.382609  ...      d
#
# [5 rows x 40 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:04:22] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[421  48 164 149]
#  [ 39 498 156 193]
#  [ 63  78 886 158]
#  [158 191 410 306]]
#
#
# Accuracy: 0.5387953037263911
#
#
# Precision: [0.61820852 0.61104294 0.54826733 0.37965261]
#
# Recall: [0.53836317 0.56207675 0.74767932 0.28732394]
#
# ...

# %%
accuracy_scores
# Out:
# []

# %% [markdown]
# #CTDT

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/output_csv_iFeature/CTDT_d.csv')
data.tail()
# Out:
#        hydrophobicity_PRAM900101.Tr1221  ...  class
# 13052                          0.308411  ...      d
# 13053                          0.229381  ...      d
# 13054                          0.204893  ...      d
# 13055                          0.220000  ...      d
# 13056                          0.289474  ...      d
#
# [5 rows x 40 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:05:10] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[370  64 183 165]
#  [ 58 464 154 210]
#  [ 77  80 848 180]
#  [169 234 354 308]]
#
#
# Accuracy: 0.5079122001020929
#
#
# Precision: [0.54896142 0.55106888 0.55100715 0.35689455]
#
# Recall: [0.47314578 0.52370203 0.71561181 0.28920188]
#
# ...

# %%
accuracy_scores
# Out:
# []

# %% [markdown]
# #CTriad

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/output_csv_iFeature/CTriad_d.csv')
data.tail()
# Out:
#        g1.g1.g1  g1.g1.g2  g1.g1.g3  ...  g7.g7.g6  g7.g7.g7  class
# 13052  0.000000  0.200000  0.800000  ...       0.0       0.0      d
# 13053  0.000000  0.125000  0.000000  ...       0.0       0.0      d
# 13054  0.083333  0.083333  0.333333  ...       0.0       0.0      d
# 13055  0.066667  0.466667  0.066667  ...       0.0       0.0      d
# 13056  0.500000  0.000000  0.000000  ...       0.0       0.0      d
#
# [5 rows x 344 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:05:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[294  77 189 222]
#  [ 72 411 159 244]
#  [ 47  64 875 199]
#  [149 241 290 385]]
#
#
# Accuracy: 0.501531393568147
#
#
# Precision: [0.52313167 0.51828499 0.57832122 0.36666667]
#
# Recall: [0.37595908 0.46388262 0.73839662 0.36150235]
#
# ...

# %%
accuracy_scores
# Out:
# []

# %% [markdown]
# #AAC

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/output_csv_iFeature/AAC_d.csv')
data.tail()
# Out:
#               A         C         D  ...         W         Y  class
# 13052  0.111628  0.009302  0.097674  ...  0.018605  0.013953      d
# 13053  0.046272  0.002571  0.051414  ...  0.007712  0.048843      d
# 13054  0.056489  0.000000  0.080916  ...  0.004580  0.038168      d
# 13055  0.053763  0.007680  0.056836  ...  0.023041  0.044547      d
# 13056  0.052174  0.034783  0.034783  ...  0.000000  0.069565      d
#
# [5 rows x 21 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:06:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[440  44 126 172]
#  [ 38 513 136 199]
#  [ 72  89 853 171]
#  [140 207 332 386]]
#
#
# Accuracy: 0.5594691168963757
#
#
# Precision: [0.63768116 0.6014068  0.58949551 0.41594828]
#
# Recall: [0.56265985 0.57900677 0.71983122 0.36244131]
#
# ...

# %%
accuracy_scores
# Out:
# []

# %% [markdown]
# #GAAC

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/output_csv_iFeature/GAAC_d.csv')
data.tail()
# Out:
#        alphatic  aromatic  postivecharge  negativecharge  uncharge class
# 13052  0.348837  0.055814       0.162791        0.186047  0.246512     d
# 13053  0.326478  0.082262       0.187661        0.167095  0.236504     d
# 13054  0.345038  0.100763       0.183206        0.163359  0.207634     d
# 13055  0.324117  0.122888       0.187404        0.119816  0.245776     d
# 13056  0.295652  0.095652       0.217391        0.104348  0.286957     d

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:06:27] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[194 131 252 205]
#  [ 82 348 272 184]
#  [ 78 103 835 169]
#  [139 207 456 263]]
#
#
# Accuracy: 0.41858090862685043
#
#
# Precision: [0.39350913 0.44106464 0.4600551  0.32034105]
#
# Recall: [0.24808184 0.39277652 0.70464135 0.24694836]
#
# ...

# %%
accuracy_scores
# Out:
# []

# %% [markdown]
# #Combined Features

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/output_csv_iFeature/Combined_d.csv')
data.tail()
# Out:
#               A         C         D  ...  g7.g7.g6  g7.g7.g7  class
# 13052  0.111628  0.009302  0.097674  ...       0.0       0.0      d
# 13053  0.046272  0.002571  0.051414  ...       0.0       0.0      d
# 13054  0.056489  0.000000  0.080916  ...       0.0       0.0      d
# 13055  0.053763  0.007680  0.056836  ...       0.0       0.0      d
# 13056  0.052174  0.034783  0.034783  ...       0.0       0.0      d
#
# [5 rows x 447 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:06:35] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[441  24 135 182]
#  [ 28 547 109 202]
#  [ 52  58 907 168]
#  [135 204 286 440]]
#
#
# Accuracy: 0.5959673302705462
#
#
# Precision: [0.6722561  0.65666267 0.63117606 0.44354839]
#
# Recall: [0.56393862 0.61738149 0.76540084 0.41314554]
#
# ...

# %%
accuracy_scores
# Out:
# []

# %%
import matplotlib.pyplot as plt

# %%
features= ['CTDC','CTDT','CTriad','AAC','GAAC', 'Combined']

# %%
accuracy_scores = np.array(accuracy_scores)
accuracy_scores=accuracy_scores*100

# %%
accuracy_scores
# Out:
# array([], dtype=float64)

# %%
plt.bar(features, accuracy_scores, color ='orange',width = 0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-5ae852bde770> in <module>()
# ----> 1 plt.bar(features, accuracy_scores, color ='orange',width = 0.2)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
plt.plot(features, accuracy_scores)

# %% [markdown]
# #PSSM

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/output_csv_iFeature/output_PSSM.csv')
data.tail()
# Out:
#              #  Pos.1.A  Pos.1.R  ...  Pos.80.W  Pos.80.Y  Pos.80.V
# 11682  d4ogca3      0.0     -2.0  ...      -3.0      -2.0      -2.0
# 11683  d5axwa3     -1.0     -3.0  ...       4.0      -1.0      -3.0
# 11684  d4oo8a3      4.0     -1.0  ...      -2.0      -1.0       1.0
# 11685  d3jb9a5     -1.0     -2.0  ...      -4.0      -2.0      -3.0
# 11686  d5gmkf_      1.0     -1.0  ...      -3.0      -2.0       2.0
#
# [5 rows x 1601 columns]

# %%
data = data.drop(data.columns[[0]],axis = 1)
data.tail()
# Out:
#        Pos.1.A  Pos.1.R  Pos.1.N  ...  Pos.80.W  Pos.80.Y  Pos.80.V
# 11682      0.0     -2.0      0.0  ...      -3.0      -2.0      -2.0
# 11683     -1.0     -3.0     -3.0  ...       4.0      -1.0      -3.0
# 11684      4.0     -1.0     -2.0  ...      -2.0      -1.0       1.0
# 11685     -1.0     -2.0     -3.0  ...      -4.0      -2.0      -3.0
# 11686      1.0     -1.0      1.0  ...      -3.0      -2.0       2.0
#
# [5 rows x 1600 columns]

# %%
classes = pd.read_csv("/content/drive/MyDrive/Project/classes_d_len80_forpssm2.csv")
classes.tail()
# Out:
#       class
# 11682     d
# 11683     d
# 11684     d
# 11685     d
# 11686     d

# %%
data = pd.concat([data, classes], axis=1)
data.tail()
# Out:
#        Pos.1.A  Pos.1.R  Pos.1.N  Pos.1.D  ...  Pos.80.W  Pos.80.Y  Pos.80.V  class
# 11682      0.0     -2.0      0.0     -1.0  ...      -3.0      -2.0      -2.0      d
# 11683     -1.0     -3.0     -3.0     -3.0  ...       4.0      -1.0      -3.0      d
# 11684      4.0     -1.0     -2.0     -2.0  ...      -2.0      -1.0       1.0      d
# 11685     -1.0     -2.0     -3.0     -3.0  ...      -4.0      -2.0      -3.0      d
# 11686      1.0     -1.0      1.0      0.0  ...      -3.0      -2.0       2.0      d
#
# [5 rows x 1601 columns]

# %%
data.to_csv("/content/drive/MyDrive/Project/output_csv_iFeature/PSSM_d.csv",index=False)

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:09:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[249 101  95 158]
#  [ 35 454 112 164]
#  [ 45  68 913 188]
#  [ 89 137 253 446]]
#
#
# Accuracy: 0.5879669232962647
#
#
# Precision: [0.59569378 0.59736842 0.66496723 0.4665272 ]
#
# Recall: [0.41293532 0.59346405 0.75205931 0.48216216]
#
# ...

# %% [markdown]
# #PCA Pssm - ncomponent 10

# %%
data = pd.read_csv("/content/drive/MyDrive/Project/output_csv_iFeature/output_pca_pssm_10.csv")
data.tail()
# Out:
#             pc.1       pc.2      pc.3  ...      pc.9     pc.10  class
# 11682 -19.198139  -2.158412 -0.642224  ...  5.649184 -4.174807      d
# 11683 -18.418969  -4.861045 -3.597764  ...  1.631262 -0.902593      d
# 11684 -23.642802  -6.241342  1.177693  ...  8.635386 -0.366495      d
# 11685 -23.149615 -10.357959 -6.573455  ... -3.970953  2.994734      d
# 11686 -27.678115  -5.570067 -1.728095  ... -0.201441  5.076239      d
#
# [5 rows x 11 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:11:59] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[183 158 107 155]
#  [ 71 405 152 137]
#  [ 71 111 837 195]
#  [124 187 301 313]]
#
#
# Accuracy: 0.4955802680353579
#
#
# Precision: [0.40757238 0.47038328 0.59914102 0.39125   ]
#
# Recall: [0.30348259 0.52941176 0.68945634 0.33837838]
#
# ...

# %%
data = pd.read_csv("/content/drive/MyDrive/Project/output_csv_iFeature/output_pca_pssm_3.csv")
data.tail()
# Out:
#             pc.1       pc.2      pc.3 class
# 11682 -19.198137  -2.160867  0.005685     d
# 11683 -18.418964  -4.870110  2.891540     d
# 11684 -23.642806  -6.245514 -1.058418     d
# 11685 -23.149620 -10.351077  7.675964     d
# 11686 -27.678111  -5.575465  1.240665     d

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:12:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[108 222 146 127]
#  [ 99 355 144 167]
#  [ 55 120 822 217]
#  [ 89 213 340 283]]
#
#
# Accuracy: 0.4471057884231537
#
#
# Precision: [0.30769231 0.39010989 0.5661157  0.35642317]
#
# Recall: [0.17910448 0.46405229 0.67710049 0.30594595]
#
# ...

# %% [markdown]
# #AAC_PSSM

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/Features_PSSM/AAC_PSSM.csv')
data.tail()
# Out:
#            V1      V2      V3      V4  ...     V19     V20       d1  class
# 13030 -0.5810 -1.2381 -0.9238 -0.8952  ... -1.6095 -0.6476  g2a73.1      b
# 13031 -0.9428 -2.4410 -2.0996 -2.5793  ... -2.6734 -2.1679  g2dg5.1      d
# 13032 -0.5243 -1.6214 -2.2621 -2.2816  ... -1.9612 -0.8155  g2vt1.1      d
# 13033 -0.6238 -1.6535 -2.0495 -2.0990  ... -1.8218 -0.8713  g3bzy.1      d
# 13034 -0.6218 -1.4538 -0.7059 -1.1261  ... -1.3613 -0.4874  g3n55.1      b
#
# [5 rows x 22 columns]

# %%
data=data.drop(columns=['d1'],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13035 entries, 0 to 13034
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      13035 non-null  float64
#  1   V2      13035 non-null  float64
#  2   V3      13035 non-null  float64
#  3   V4      13035 non-null  float64
#  4   V5      13035 non-null  float64
#  5   V6      13035 non-null  float64
#  6   V7      13035 non-null  float64
#  7   V8      13035 non-null  float64
#  8   V9      13035 non-null  float64
#  9   V10     13035 non-null  float64
#  10  V11     13035 non-null  float64
#  11  V12     13035 non-null  float64
#  12  V13     13035 non-null  float64
#  13  V14     13035 non-null  float64
#  14  V15     13035 non-null  float64
#  15  V16     13035 non-null  float64
#  16  V17     13035 non-null  float64
#  17  V18     13035 non-null  float64
#  18  V19     13035 non-null  float64
#  19  V20     13035 non-null  float64
# ...

# %%
classModel(data)
# Out:
# [14:12:12] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Confusion matrix:
#  [[ 570   35   62  105]
#  [  35  608   48  134]
#  [  24   53 1081  135]
#  [  94  166  182  579]]
#
#
# Accuracy: 0.7256456149322424
#
#
# Precision: [0.78838174 0.70533643 0.78732702 0.60755509]
#
# Recall: [0.73834197 0.7369697  0.83604022 0.56709109]
#
# ...

# %% [markdown]
# #GREY_PSSM

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/Features_PSSM/GREY_PSSM.csv')
data.tail()

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:12:30] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[ 421   48  117  186]
#  [  65  457   96  207]
#  [  51   52 1013  177]
#  [ 137  201  237  446]]
#
#
# Accuracy: 0.5975453848120685
#
#
# Precision: [0.62462908 0.60290237 0.69241285 0.43897638]
#
# Recall: [0.54533679 0.55393939 0.78344934 0.43682664]
#
# ...

# %% [markdown]
# #AB_PSSM

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/Features_PSSM/AB_PSSM.csv')
data.tail()
# Out:
#            V1      V2      V3      V4  ...    V398    V399    V400  class
# 13030 -0.2000 -2.2000 -0.8000 -0.2000  ... -2.5000 -1.4000 -0.4000      b
# 13031  0.5926 -2.1481 -2.5185 -3.1111  ... -3.0345 -2.3793 -2.1379      d
# 13032 -0.2000 -0.6000 -2.4000 -2.8000  ... -2.3750 -0.5000 -0.2500      d
# 13033 -0.4000  0.4000 -0.8000 -3.0000  ... -1.5000 -0.3333 -1.1667      d
# 13034  0.0000 -1.8000 -1.4000 -2.0000  ... -2.8750 -1.5417 -0.6250      b
#
# [5 rows x 401 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:31] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[ 500   49   94  129]
#  [  54  535   67  169]
#  [  26   53 1107  107]
#  [  98  140  191  592]]
#
#
# Accuracy: 0.6990539503963181
#
#
# Precision: [0.73746313 0.68854569 0.75873886 0.59378134]
#
# Recall: [0.64766839 0.64848485 0.85614849 0.5798237 ]
#
# ...

# %% [markdown]
# #DISCRETE_COSINE_PSSM

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/Features_PSSM/DISCRETE_COSINE_PSSM.csv')
data.tail()
# Out:
#            V1      V2      V3      V4  ...    V398    V399    V400  class
# 13030  5.5130  1.7498  0.1940 -0.6628  ...  0.6068 -0.5769  0.5609      b
# 13031  6.1767  1.9361 -0.2618 -0.3771  ...  0.1105 -0.5661  1.2490      d
# 13032  4.6730 -1.2496 -1.6601  0.4356  ...  1.3569 -1.1917  0.3662      d
# 13033  6.6466  1.7234  0.5494 -0.3411  ...  0.7958 -0.6276  0.7273      d
# 13034  3.8496  1.0539  0.1744 -0.1114  ...  1.0053 -0.3285  0.0916      b
#
# [5 rows x 401 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:17:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[366 125 131 150]
#  [ 67 423 139 196]
#  [ 85 104 887 217]
#  [127 181 240 473]]
#
#
# Accuracy: 0.5494758373817438
#
#
# Precision: [0.56744186 0.50780312 0.634932   0.45656371]
#
# Recall: [0.47409326 0.51272727 0.68600155 0.4632713 ]
#
# ...

# %% [markdown]
# #PSSM400

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/Features_PSSM/PSSM400.csv')
data.tail()
# Out:
#             V1       V2       V3       V4  ...  V398  V399  V400  class
# 13030   2.2857   0.8571   0.5714   0.5714  ...   0.0   0.0   0.0      b
# 13031  38.2727  20.8636  20.5000  19.0455  ...   0.0   0.0   0.0      d
# 13032   4.5000   2.0000   2.1111   1.9444  ...   0.0   0.0   0.0      d
# 13033   5.0000   1.7895   1.7368   1.6316  ...   0.0   0.0   0.0      d
# 13034   2.8571   1.2857   1.3571   1.2857  ...   0.0   0.0   0.0      b
#
# [5 rows x 401 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:21:39] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[ 421   48  117  186]
#  [  65  457   96  207]
#  [  51   52 1013  177]
#  [ 137  201  237  446]]
#
#
# Accuracy: 0.5975453848120685
#
#
# Precision: [0.62462908 0.60290237 0.69241285 0.43897638]
#
# Recall: [0.54533679 0.55393939 0.78344934 0.43682664]
#
# ...

# %% [markdown]
# #RPSSM_PSSM

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/Features_PSSM/RPSSM_PSSM.csv')
data.tail()
# Out:
#            V1       V2       V3      V4  ...    V108     V109     V110  class
# 13030  2.3558   3.6261   4.8492  2.8958  ...  3.4146   5.4498   4.9047      b
# 13031  9.5781  10.7019  11.3658  8.7541  ...  5.2802  15.8761  14.8015      d
# 13032  6.4096   8.3931   9.6166  5.3976  ...  4.1964   7.5608  11.1109      d
# 13033  6.2961   7.5082   8.5778  5.2894  ...  4.2545   7.5389  10.8825      d
# 13034  3.5753   3.5210   4.3666  3.4426  ...  2.9341   6.5654   6.0306      b
#
# [5 rows x 111 columns]

# %%
classModel(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:23:58] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Confusion matrix:
#  [[ 602   40   35   95]
#  [  38  611   47  129]
#  [  27   46 1101  119]
#  [  98  149  165  609]]
#
#
# Accuracy: 0.747379186908719
#
#
# Precision: [0.7869281  0.72222222 0.81676558 0.63970588]
#
# Recall: [0.77979275 0.74060606 0.85150812 0.59647405]
#
# ...

# %%
def classModel2(data):
  X= data.iloc[:,:-1].values
  y= data.iloc[:,-1].values
  
  le = LabelEncoder()
  print(y)
  y= le.fit_transform(y) 
  print(y)

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 5)

  model = XGBClassifier(objective='multi:softmax')
  print(model.objective)
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)

  print('\nClassification report:\n', classification_report(y_test,y_pred))
  print('Confusion matrix: \n', confusion_matrix(y_test,y_pred))

  accuracy = accuracy_score(y_test,y_pred)
  # accuracy_scores.append(accuracy)
  print("\n\nAccuracy:",accuracy_score(y_test, y_pred))

  print("\n\nPrecision:",precision_score(y_test, y_pred, average=None))
  print("\nRecall:",recall_score(y_test, y_pred, average=None))
  print("\nF1 score:",f1_score(y_test, y_pred, average=None))

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/Features_PSSM/RPSSM_PSSM.csv')
data.tail()
# Out:
#            V1       V2       V3      V4  ...    V108     V109     V110  class
# 13030  2.3558   3.6261   4.8492  2.8958  ...  3.4146   5.4498   4.9047      b
# 13031  9.5781  10.7019  11.3658  8.7541  ...  5.2802  15.8761  14.8015      d
# 13032  6.4096   8.3931   9.6166  5.3976  ...  4.1964   7.5608  11.1109      d
# 13033  6.2961   7.5082   8.5778  5.2894  ...  4.2545   7.5389  10.8825      d
# 13034  3.5753   3.5210   4.3666  3.4426  ...  2.9341   6.5654   6.0306      b
#
# [5 rows x 111 columns]

# %%
classModel2(data)
# Out:
# ['d' 'd' 'd' ... 'd' 'd' 'b']
# [3 3 3 ... 3 3 1]
# multi:softmax
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:25:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       772
#            1       0.72      0.74      0.73       825
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Project/Features_PSSM
# !pwd
# Out:
# /content/drive/MyDrive/Project/Features_PSSM
# /content/drive/MyDrive/Project/Features_PSSM

# %%
files= ['AADP_PSSM.csv', 'DPC_PSSM.csv', 'DFMCA_PSSM.csv', 'LPC_PSSM.csv', 'MBMGAC_PSSM.csv']

# %%
def automation(filenames):
  size= len(filenames)
  for i in range(size):
    print()
    print()
    print("Feature Name: ", filenames[i])
    print()
    data = pd.read_csv(filenames[i])
    classModel2(data)

# %%
automation(files)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87       772
#            1       0.79      0.84      0.81       825
#            2       0.87      0.90      0.89      1293
#            3       0.76      0.71      0.73      1021
#
#     accuracy                           0.83      3911
#    macro avg       0.83      0.83      0.83      3911
# weighted avg       0.83      0.83      0.83      3911
#
# Confusion matrix:
#  [[ 656   20   34   62]
#  [  14  694   25   92]
#  [  14   35 1166   78]
#  [  51  132  114  724]]
#
#
# Accuracy: 0.828432625926873
#
#
# Precision: [0.89251701 0.7877412  0.8707991  0.75732218]
#
# Recall: [0.84974093 0.84121212 0.90177881 0.70910872]
#
# F1 score: [0.87060385 0.81359906 0.88601824 0.73242286]

# %%
output_files= ['SOMA_PSSM.csv', 'SINGLE_AVERAGE_PSSM.csv', 'SVD_PSSM.csv']

# %%
automation(output_files)
# Out:
# Feature Name:  SOMA_PSSM.csv
#
# ['d' 'd' 'd' ... 'd' 'd' 'b']
# [3 3 3 ... 3 3 1]
# multi:softmax
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:45:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       772
# ...

# %%
files= ['AATP_TPCC.csv',
               'K_SEPERATED_BIGRAME.csv',
               'CS_PSE_PSSM.csv',
               'DWT_PSSM.csv',
               'EDP_MEDP.csv',
               'FPSSM.csv',
               'PSSMBLOCK.csv',
               'SCSH2.csv',
               'TRIGRAME_PSSM.csv'
               ]

# %%
automation(files)
# Out:
# Feature Name:  AATP_TPCC.csv
#
# ['d' 'd' 'd' ... 'd' 'd' 'b']
# [3 3 3 ... 3 3 1]
# multi:softmax
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:49:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       772
# ...

# %%
df1= pd.read_csv('MBMGAC_PSSM.csv')
df1.tail()
# Out:
#           V1     V2     V3     V4  ...        V558        V559        V560  class
# 13030  0.367  0.278  0.356  0.324  ...   11440.514    9073.175    9461.005      b
# 13031  0.372  0.273  0.284  0.273  ...  288840.762  287647.980  303895.461      d
# 13032  0.392  0.326  0.249  0.261  ...    9310.609    8159.080    8141.003      d
# 13033  0.376  0.320  0.267  0.266  ...    8891.549    7769.568    7952.767      d
# 13034  0.361  0.240  0.360  0.292  ...   13803.527   12025.509   11144.905      b
#
# [5 rows x 561 columns]

# %%
df2= pd.read_csv( 'CS_PSE_PSSM.csv')
df2.tail()
# Out:
#             1       2       3       4  ...     698     699     700  class
# 13030  0.0476  0.0190  0.0286  0.0857  ... -0.0055 -0.0025  0.0060      b
# 13031  0.0941  0.0590  0.0554  0.0738  ... -0.0101  0.0023 -0.0004      d
# 13032  0.1456  0.0680  0.0097  0.0680  ...  0.0104  0.0146  0.0179      d
# 13033  0.1386  0.0396  0.0099  0.0594  ...  0.0047  0.0046  0.0168      d
# 13034  0.0504  0.0168  0.0840  0.0840  ...  0.0088  0.0234 -0.0196      b
#
# [5 rows x 701 columns]

# %%
df2=df2.drop(columns=['class'], axis=1)
df2.tail()
# Out:
#             1       2       3       4  ...     697     698     699     700
# 13030  0.0476  0.0190  0.0286  0.0857  ... -0.0007 -0.0055 -0.0025  0.0060
# 13031  0.0941  0.0590  0.0554  0.0738  ...  0.0096 -0.0101  0.0023 -0.0004
# 13032  0.1456  0.0680  0.0097  0.0680  ... -0.0051  0.0104  0.0146  0.0179
# 13033  0.1386  0.0396  0.0099  0.0594  ... -0.0051  0.0047  0.0046  0.0168
# 13034  0.0504  0.0168  0.0840  0.0840  ... -0.0003  0.0088  0.0234 -0.0196
#
# [5 rows x 700 columns]

# %%
df3=pd.concat([df2,df1], axis=1)
df3.tail()
# Out:
#             1       2       3  ...        V559        V560  class
# 13030  0.0476  0.0190  0.0286  ...    9073.175    9461.005      b
# 13031  0.0941  0.0590  0.0554  ...  287647.980  303895.461      d
# 13032  0.1456  0.0680  0.0097  ...    8159.080    8141.003      d
# 13033  0.1386  0.0396  0.0099  ...    7769.568    7952.767      d
# 13034  0.0504  0.0168  0.0840  ...   12025.509   11144.905      b
#
# [5 rows x 1261 columns]

# %%
df3.to_csv('combined_CS_PSE_MBMGAC.csv', index=False)

# %%
automation(['combined_CS_PSE_MBMGAC.csv'])
# Out:
# Feature Name:  combined_CS_PSE_MBMGAC.csv
#
# ['d' 'd' 'd' ... 'd' 'd' 'b']
# [3 3 3 ... 3 3 1]
# multi:softmax
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11:10:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       772
# ...

# %% [markdown]
# #Using combined of some features which gave >=70

# %%
automation(['combined_pssm.csv'])

# %%
# !pip install -U xgboost

# %%
import pickle

# %%
data=pd.read_csv('combined_pssm.csv')
data.tail()

# %% [markdown]
# #using gpu on combined features

# %%
X= data.iloc[:,:-1].values
y= data.iloc[:,-1].values
  
le = LabelEncoder()
print(y)
y= le.fit_transform(y) 
print(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 5)

model = XGBClassifier(tree_method='gpu_hist',use_label_encoder=False)
model.fit(X_train, y_train)

pickle.dump(model, open("model.pickle.dat", "wb"))

y_pred = model.predict(X_test)

print('\nClassification report:\n', classification_report(y_test,y_pred))
print('Confusion matrix: \n', confusion_matrix(y_test,y_pred))

accuracy = accuracy_score(y_test,y_pred)
# accuracy_scores.append(accuracy)
print("\n\nAccuracy:",accuracy_score(y_test, y_pred))

print("\n\nPrecision:",precision_score(y_test, y_pred, average=None))
print("\nRecall:",recall_score(y_test, y_pred, average=None))
print("\nF1 score:",f1_score(y_test, y_pred, average=None))

# %% [markdown]
# #some change  in parameter of model

# %%
accuracy_scores=[]

# %%
# %cd

# %%
def classModel3(data):
  X= data.iloc[:,:-1].values
  y= data.iloc[:,-1].values
  
  le = LabelEncoder()
  print(y)
  y= le.fit_transform(y) 
  print(y)

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 5)

  model = XGBClassifier(tree_method='gpu_hist',use_label_encoder=False)
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)

  print('\nClassification report:\n', classification_report(y_test,y_pred))
  print('Confusion matrix: \n', confusion_matrix(y_test,y_pred))

  accuracy = accuracy_score(y_test,y_pred)
  accuracy_scores.append(accuracy)
  print("\n\nAccuracy:",accuracy_score(y_test, y_pred))

  print("\n\nPrecision:",precision_score(y_test, y_pred, average=None))
  print("\nRecall:",recall_score(y_test, y_pred, average=None))
  print("\nF1 score:",f1_score(y_test, y_pred, average=None))

# %%
def automation(filenames):
  size= len(filenames)
  for i in range(size):
    print()
    print()
    print("Feature Name: ", filenames[i])
    print()
    data = pd.read_csv(filenames[i])
    classModel3(data)

# %%
files= ['AADP_PSSM.csv', 'DPC_PSSM.csv', 'DFMCA_PSSM.csv', 'LPC_PSSM.csv', 'MBMGAC_PSSM.csv',
        'SOMA_PSSM.csv', 'SINGLE_AVERAGE_PSSM.csv', 'SVD_PSSM.csv',
        'AATP_TPCC.csv',
               'K_SEPERATED_BIGRAME.csv',
               'CS_PSE_PSSM.csv',
               'DWT_PSSM.csv',
               'EDP_MEDP.csv',
               'FPSSM.csv',
               'PSSMBLOCK.csv',
               'SCSH2.csv',
               'TRIGRAME_PSSM.csv',
                'combined_CS_PSE_MBMGAC.csv',
        'combined_pssm.csv'
               ]

# %%
automation(files)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(files, accuracy_scores, color ='orange',width = 0.2)

# %%
plt.plot(files,accuracy_scores)

# %%
plt.scatter(files,accuracy_scores)
