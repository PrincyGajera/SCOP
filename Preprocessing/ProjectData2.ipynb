# %%
import pandas as pd

# %%
df1=pd.read_csv("/content/drive/MyDrive/Project/sequences2_d.csv")
df1.tail()
# Out:
#       Descriptor                                           Sequence
# 13052   >d4ogca3  gsavsrvapdplpgqgsfrrapkcdpefqrfriisivanlrisetk...
# 13053   >d5axwa3  vennegrrskrgarrlkrrrrhriqrvkkllfdynlltdhselsgi...
# 13054   >d4oo8a3  aeatrlkrtarrrytrrknrilylqeifsnemakvddsffhrlees...
# 13055   >d3jb9a5  lekqlnerarkwrasqkskfgvkrkqgyvqtekadlppehlrkimk...
# 13056   >d5gmkf_  serkainkyyppdynpleaeklsrkmakklktmnkshasirlmtpf...

# %%
classes= pd.read_csv("/content/drive/MyDrive/Project/classes_d.csv")
classes.tail()
# Out:
#       class
# 13052     d
# 13053     d
# 13054     d
# 13055     d
# 13056     d

# %%
df=pd.concat([df1,classes], axis=1)
df.tail()
# Out:
#       Descriptor                                           Sequence class
# 13052   >d4ogca3  gsavsrvapdplpgqgsfrrapkcdpefqrfriisivanlrisetk...     d
# 13053   >d5axwa3  vennegrrskrgarrlkrrrrhriqrvkkllfdynlltdhselsgi...     d
# 13054   >d4oo8a3  aeatrlkrtarrrytrrknrilylqeifsnemakvddsffhrlees...     d
# 13055   >d3jb9a5  lekqlnerarkwrasqkskfgvkrkqgyvqtekadlppehlrkimk...     d
# 13056   >d5gmkf_  serkainkyyppdynpleaeklsrkmakklktmnkshasirlmtpf...     d

# %%
df2= pd.read_csv("/content/drive/MyDrive/Project/Features_PSSM/AAC_PSSM2.csv")
df2.head()
# Out:
#    Unnamed: 0 pssm_short_names  ...     V19     V20
# 0           1     d12asa_.pssm  ... -1.5291 -1.2630
# 1           2     d16vpa_.pssm  ... -1.1629 -0.9747
# 2           3     d1914a1.pssm  ... -1.1026 -0.8205
# 3           4     d1914a2.pssm  ... -1.3814 -0.7216
# 4           5     d1a04a1.pssm  ... -3.3881 -2.0896
#
# [5 rows x 24 columns]

# %%
df2=df2.drop(df2.columns[0], axis=1)

# %%
df2=df2.drop(columns=['pssm_names', 'X'], axis=1)

# %%
df2[['d1','d2']]=df2['pssm_short_names'].str.split('.pssm', n=1, expand=True) 
df2.tail()
# Out:
#       pssm_short_names      V1      V2      V3  ...     V19     V20       d1  d2
# 14225     g2a73.1.pssm -0.5810 -1.2381 -0.9238  ... -1.6095 -0.6476  g2a73.1
# 14226     g2dg5.1.pssm -0.9428 -2.4410 -2.0996  ... -2.6734 -2.1679  g2dg5.1
# 14227     g2vt1.1.pssm -0.5243 -1.6214 -2.2621  ... -1.9612 -0.8155  g2vt1.1
# 14228     g3bzy.1.pssm -0.6238 -1.6535 -2.0495  ... -1.8218 -0.8713  g3bzy.1
# 14229     g3n55.1.pssm -0.6218 -1.4538 -0.7059  ... -1.3613 -0.4874  g3n55.1
#
# [5 rows x 23 columns]

# %%
df2=df2.drop(columns=['pssm_short_names', 'd2'], axis=1)
df2.head()
# Out:
#        V1      V2      V3      V4  ...     V18     V19     V20       d1
# 0 -0.9358 -1.1131 -1.3547 -1.3731  ... -2.7676 -1.5291 -1.2630  d12asa_
# 1 -0.3848 -0.8455 -1.0393 -1.3680  ... -2.2837 -1.1629 -0.9747  d16vpa_
# 2 -0.6795 -0.4744 -0.7821 -1.2179  ... -2.3590 -1.1026 -0.8205  d1914a1
# 3 -0.4330 -0.4330 -0.8557 -1.2887  ... -2.3196 -1.3814 -0.7216  d1914a2
# 4 -1.3881 -1.6269 -2.5821 -3.0299  ... -4.9552 -3.3881 -2.0896  d1a04a1
#
# [5 rows x 21 columns]

# %%
df2.tail()
# Out:
#            V1      V2      V3      V4  ...     V18     V19     V20       d1
# 14225 -0.5810 -1.2381 -0.9238 -0.8952  ... -2.3619 -1.6095 -0.6476  g2a73.1
# 14226 -0.9428 -2.4410 -2.0996 -2.5793  ... -3.7306 -2.6734 -2.1679  g2dg5.1
# 14227 -0.5243 -1.6214 -2.2621 -2.2816  ... -3.6796 -1.9612 -0.8155  g2vt1.1
# 14228 -0.6238 -1.6535 -2.0495 -2.0990  ... -3.5743 -1.8218 -0.8713  g3bzy.1
# 14229 -0.6218 -1.4538 -0.7059 -1.1261  ... -2.6303 -1.3613 -0.4874  g3n55.1
#
# [5 rows x 21 columns]

# %%
df[['t','d1']]=df['Descriptor'].str.split('>', n=1, expand=True) 
df.tail()
# Out:
#       Descriptor                                           Sequence  ... t       d1
# 13052   >d4ogca3  gsavsrvapdplpgqgsfrrapkcdpefqrfriisivanlrisetk...  ...    d4ogca3
# 13053   >d5axwa3  vennegrrskrgarrlkrrrrhriqrvkkllfdynlltdhselsgi...  ...    d5axwa3
# 13054   >d4oo8a3  aeatrlkrtarrrytrrknrilylqeifsnemakvddsffhrlees...  ...    d4oo8a3
# 13055   >d3jb9a5  lekqlnerarkwrasqkskfgvkrkqgyvqtekadlppehlrkimk...  ...    d3jb9a5
# 13056   >d5gmkf_  serkainkyyppdynpleaeklsrkmakklktmnkshasirlmtpf...  ...    d5gmkf_
#
# [5 rows x 5 columns]

# %%
df=df.drop(columns=['t'], axis=1)
df.head()
# Out:
#   Descriptor                                           Sequence class       d1
# 0   >d1dlwa_  slfeqlggqaavqavtaqfyaniqadatvatffngidmpnqtnkta...     a  d1dlwa_
# 1   >d2gkma_  gllsrlrkrepisiydkiggheaievvvedffvrvladdqlsaffs...     a  d2gkma_
# 2   >d1ngka_  ksfydavggaktfdaivsrfyaqvaedevlrrvypeddlagaeerl...     a  d1ngka_
# 3   >d2bkma_  eqwqtlyeaiggeetvaklveafyrrvaahpdlrpifpddltetah...     a  d2bkma_
# 4   >d4i0va_  aslyeklggaaavdlavekfygkvladervnrffvntdmakqkqhq...     a  d4i0va_

# %%
df2["class"]=""
df2.head()
# Out:
#        V1      V2      V3      V4  ...     V19     V20       d1  class
# 0 -0.9358 -1.1131 -1.3547 -1.3731  ... -1.5291 -1.2630  d12asa_
# 1 -0.3848 -0.8455 -1.0393 -1.3680  ... -1.1629 -0.9747  d16vpa_
# 2 -0.6795 -0.4744 -0.7821 -1.2179  ... -1.1026 -0.8205  d1914a1
# 3 -0.4330 -0.4330 -0.8557 -1.2887  ... -1.3814 -0.7216  d1914a2
# 4 -1.3881 -1.6269 -2.5821 -3.0299  ... -3.3881 -2.0896  d1a04a1
#
# [5 rows x 22 columns]

# %%
df2.iloc[0,20]
# Out:
# 'd12asa_'

# %%
type(df.iloc[0,2])
# Out:
# str

# %%
df.iloc[0,3]
# Out:
# 'd1dlwa_'

# %%
index_to_remove=[]
for i in range(0,14230):
  flag=0
  for j in range(0,13057):
    if(df2.iloc[i,20]==df.iloc[j,3]):
      flag=1

      df2.at[i, 'class']= df.iloc[j,2]
      break
  if(flag==0):
    index_to_remove.append(i)
    df2.at[i, 'class']= 'x'

# %%
index_to_remove
# Out:
# [11,
#  15,
#  35,
#  64,
#  66,
#  69,
#  70,
#  71,
#  76,
#  78,
#  79,
#  80,
#  89,
#  96,
#  102,
#  106,
#  115,
#  116,
#  123,
#  127,
#  135,
#  140,
#  188,
#  194,
#  201,
#  202,
#  203,
#  214,
#  228,
#  236,
#  240,
#  251,
#  261,
#  262,
#  274,
#  279,
#  280,
#  294,
#  304,
#  318,
#  326,
#  335,
#  343,
#  347,
#  370,
#  378,
#  381,
#  383,
#  386,
#  402,
#  406,
#  409,
#  425,
#  450,
#  457,
#  459,
#  471,
#  482,
#  506,
#  507,
#  512,
#  531,
#  534,
#  537,
#  541,
#  545,
#  547,
#  554,
#  579,
#  585,
#  590,
#  591,
#  595,
#  597,
#  604,
#  608,
#  609,
#  610,
#  623,
#  629,
#  652,
#  672,
#  699,
#  729,
#  735,
#  740,
#  743,
#  752,
#  762,
#  766,
#  788,
#  793,
#  797,
#  798,
#  825,
#  827,
#  828,
#  829,
#  830,
#  832,
#  846,
#  900,
#  905,
#  914,
#  915,
#  926,
#  933,
#  936,
#  938,
#  939,
#  966,
#  973,
#  981,
#  1001,
#  1010,
#  1013,
#  1022,
#  1027,
#  1031,
#  1051,
#  1052,
#  1066,
#  1067,
#  1068,
#  1070,
# ...

# %%
index = pd.DataFrame(index_to_remove,columns =['Index'])
index.head()
# Out:
#    Index
# 0     11
# 1     15
# 2     35
# 3     64
# 4     66

# %%
index_remove=[11,
 15,
 35,
 64,
 66,
 69,
 70,
 71,
 76,
 78,
 79,
 80,
 89,
 96,
 102,
 106,
 115,
 116,
 123,
 127,
 135,
 140,
 188,
 194,
 201,
 202,
 203,
 214,
 228,
 236,
 240,
 251,
 261,
 262,
 274,
 279,
 280,
 294,
 304,
 318,
 326,
 335,
 343,
 347,
 370,
 378,
 381,
 383,
 386,
 402,
 406,
 409,
 425,
 450,
 457,
 459,
 471,
 482,
 506,
 507,
 512,
 531,
 534,
 537,
 541,
 545,
 547,
 554,
 579,
 585,
 590,
 591,
 595,
 597,
 604,
 608,
 609,
 610,
 623,
 629,
 652,
 672,
 699,
 729,
 735,
 740,
 743,
 752,
 762,
 766,
 788,
 793,
 797,
 798,
 825,
 827,
 828,
 829,
 830,
 832,
 846,
 900,
 905,
 914,
 915,
 926,
 933,
 936,
 938,
 939,
 966,
 973,
 981,
 1001,
 1010,
 1013,
 1022,
 1027,
 1031,
 1051,
 1052,
 1066,
 1067,
 1068,
 1070,
 1079,
 1090,
 1109,
 1146,
 1148,
 1150,
 1180,
 1231,
 1254,
 1255,
 1257,
 1269,
 1299,
 1324,
 1338,
 1339,
 1347,
 1351,
 1352,
 1355,
 1367,
 1383,
 1385,
 1397,
 1407,
 1437,
 1440,
 1451,
 1456,
 1482,
 1490,
 1501,
 1506,
 1508,
 1516,
 1518,
 1535,
 1539,
 1571,
 1579,
 1588,
 1589,
 1594,
 1596,
 1630,
 1651,
 1659,
 1660,
 1675,
 1716,
 1727,
 1730,
 1750,
 1765,
 9261,
 9339,
 9351,
 9403,
 9406,
 9414,
 9438,
 9440,
 9458,
 9474,
 9476,
 9490,
 9499,
 9512,
 9530,
 9550,
 9565,
 9588,
 9599,
 9629,
 9630,
 9632,
 9634,
 9641,
 9645,
 9666,
 9667,
 9679,
 9680,
 9682,
 9683,
 9685,
 9686,
 9688,
 9689,
 9690,
 9691,
 9692,
 9715,
 9742,
 9774,
 9791,
 9799,
 9833,
 9838,
 9875,
 9880,
 9899,
 9917,
 9978,
 9988,
 10009,
 10020,
 10031,
 10032,
 10034,
 10035,
 10036,
 10037,
 10038,
 10039,
 10063,
 10064,
 10094,
 10095,
 10116,
 10117,
 10142,
 10149,
 10154,
 10155,
 10171,
 10217,
 10238,
 10255,
 10256,
 10257,
 10258,
 10297,
 10319,
 10405,
 10406,
 10413,
 10424,
 10445,
 10455,
 10456,
 10459,
 10475,
 10494,
 10516,
 10519,
 10552,
 10557,
 10565,
 10566,
 10642,
 10644,
 10666,
 10676,
 10685,
 10699,
 10705,
 10706,
 10714,
 10715,
 10716,
 10724,
 10726,
 10732,
 10734,
 10735,
 10736,
 10737,
 10738,
 10777,
 10801,
 10812,
 10818,
 10831,
 10842,
 10912,
 10929,
 10939,
 10955,
 10959,
 10970,
 10987,
 10994,
 11037,
 11042,
 11057,
 11093,
 11112,
 11114,
 11123,
 11141,
 11145,
 11165,
 11195,
 11229,
 11252,
 11258,
 11264,
 11271,
 11284,
 11300,
 11306,
 11331,
 11335,
 11343,
 11357,
 11381,
 11407,
 11450,
 11460,
 11501,
 11502,
 11503,
 11530,
 11545,
 11547,
 11555,
 ...]

# %%
index = pd.DataFrame(index_remove,columns =['Index'])
index.head()
# Out:
#   Index
# 0    11
# 1    15
# 2    35
# 3    64
# 4    66

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   1001 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
index.to_csv("/content/drive/MyDrive/Project/Features_PSSM/index_to_remove_for_features.csv",index=False)

# %%
df2.to_csv("/content/drive/MyDrive/Project/Features_PSSM/output_AAC_PSSM.csv",index=False)

# %%
i=1
df2.at[i, 'class']= ''
df2.head()
# Out:
#        V1      V2      V3      V4  ...     V19     V20       d1  class
# 0 -0.9358 -1.1131 -1.3547 -1.3731  ... -1.5291 -1.2630  d12asa_
# 1 -0.3848 -0.8455 -1.0393 -1.3680  ... -1.1629 -0.9747  d16vpa_
# 2 -0.6795 -0.4744 -0.7821 -1.2179  ... -1.1026 -0.8205  d1914a1
# 3 -0.4330 -0.4330 -0.8557 -1.2887  ... -1.3814 -0.7216  d1914a2
# 4 -1.3881 -1.6269 -2.5821 -3.0299  ... -3.3881 -2.0896  d1a04a1
#
# [5 rows x 22 columns]

# %%
header_list=['D1']
pssm_list = pd.read_csv('pssm.txt',names=header_list,header=None)
pssm_list=pssm_list.iloc[:14185,:]
pssm_list[['d1','d2']]=pssm_list['D1'].str.split('.', n=1, expand=True) 
pssm_list = pssm_list.drop(['D1','d2'], axis=1)
pssm_list['t']='>'
pssm_list['d1']=pssm_list['t']+pssm_list['d1']
pssm_list = pssm_list.drop(['t'],axis=1)
pssm_list.tail()
# Out:
#              d1
# 14180  >d7ahla_
# 14181  >d7mdha2
# 14182  >d7odca1
# 14183  >d7odca2
# 14184  >d8abpa_
